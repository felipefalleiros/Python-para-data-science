# %% [markdown]
# # Desafio 1

# %%
import pandas as pd
import json

# %%
with open('informacoes.json', 'r') as f:
  dados_brutos = json.load(f)

# %%
dados_brutos
# Out:
# {'nome': 'João',
#  'idade': 28,
#  'enderecos': [{'tipo': 'casa',
#    'rua': 'Rua A',
#    'numero': 123,
#    'cidade': 'São Paulo'},
#   {'tipo': 'trabalho',
#    'rua': 'Rua B',
#    'numero': 456,
#    'cidade': 'Rio de Janeiro'}]}

# %%
df_d1 = pd.json_normalize(dados_brutos, record_path='enderecos', meta=['nome', 'idade'], errors='ignore')

# %%
df_d1
# Out:
#        tipo    rua  numero          cidade  nome idade
# 0      casa  Rua A     123       São Paulo  João    28
# 1  trabalho  Rua B     456  Rio de Janeiro  João    28

# %% [markdown]
# # Desafio 2

# %%
import json

with open('dados_d2.json', 'r') as f:
    dados_d2 = json.load(f)

# %%
dados_d2
# Out:
# {'pessoas': [{'nome': 'João',
#    'idade': '25',
#    'endereco': {'rua': 'Rua A', 'numero': 123, 'cidade': 'São Paulo'},
#    'telefones': ['11 1111-1111', '11 2222-2222']},
#   {'nome': 'Maria',
#    'idade': 30,
#    'endereco': {'rua': '', 'numero': 456, 'cidade': 'Rio de Janeiro'},
#    'telefones': ['21 3333-3333']}]}

# %%
df_d2 = pd.json_normalize(dados_d2, record_path=['pessoas'])

# %%
df_d2
# Out:
#     nome idade                     telefones endereco.rua  endereco.numero  \
# 0   João    25  [11 1111-1111, 11 2222-2222]        Rua A              123
# 1  Maria    30                [21 3333-3333]                           456
#
#   endereco.cidade
# 0       São Paulo
# 1  Rio de Janeiro

# %%
df_d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             2 non-null      object
#  1   idade            2 non-null      object
#  2   telefones        2 non-null      object
#  3   endereco.rua     2 non-null      object
#  4   endereco.numero  2 non-null      int64
#  5   endereco.cidade  2 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 224.0+ bytes

# %%
df_d2['idade'] = df_d2['idade'].astype(int)

# %%
df_d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             2 non-null      object
#  1   idade            2 non-null      int64
#  2   telefones        2 non-null      object
#  3   endereco.rua     2 non-null      object
#  4   endereco.numero  2 non-null      int64
#  5   endereco.cidade  2 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 224.0+ bytes

# %%
# Utilização da ` para que o Pandas possa interpretá-la corretamente como uma coluna com nome contendo pontos
df_d2_filtrado = df_d2.query('`endereco.rua` != ""')

# %%
df_d2_filtrado
# Out:
#    nome  idade                     telefones endereco.rua  endereco.numero  \
# 0  João     25  [11 1111-1111, 11 2222-2222]        Rua A              123
#
#   endereco.cidade
# 0       São Paulo
